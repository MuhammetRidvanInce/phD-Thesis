# %%
"""Tablo Dönüşüm.ipynb dosyasının oluşturduğu KSH_(yıl) isimli excel dosyalarını KSH_TOPLU isimli
tek bir excel dosyasında konsolide etmektedir."""

# %%
import openpyxl as xl
import numpy as np
import pandas as pd

# %%
cols = [str(x) for x in range(2009,2021)]

inds_cells = [
            ("Çıktı", "F2"),
            ("MOŞ Çıktı", "B2"),
            ("MŞ Çıktı", "C2"),
            ("Devlet Çıktı", "D2"),
            ("HH Çıktı", "E2"),

            ("Piyasa Çıktısı", "F3"),
            ("MOŞ Piyasa Çıktısı", "B3"),
            ("MŞ Piyasa Çıktısı", "C3"),
            ("Devlet Piyasa Çıktısı", "D3"),
            ("HH Piyasa Çıktısı", "E3"),

            ("Kendi Nihai Tüketimi için Çıktı", "F4"),
            ("MOŞ Kendi Nihai Tüketimi için Çıktı", "B4"),
            ("MŞ Kendi Nihai Tüketimi için Çıktı", "C4"),
            ("Devlet Kendi Nihai Tüketimi için Çıktı", "D4"),
            ("HH Kendi Nihai Tüketimi için Çıktı", "E4"),

            ("Piyasa Dışı Çıktı", "F5"),
            ("MOŞ Piyasa Dışı Çıktı", "B5"),
            ("MŞ Piyasa Dışı Çıktı", "C5"),
            ("Devlet Piyasa Dışı Çıktı", "D5"),
            ("HH Piyasa Dışı Çıktı", "E5"),

            ("Ara Tüketim", "M6"),
            ("MOŞ Ara Tüketim", "I6"),
            ("MŞ Ara Tüketim", "J6"),
            ("Devlet Ara Tüketim", "K6"),
            ("HH Ara Tüketim", "L6"),

            ("GS Katma Değer", "M7"),
            ("MOŞ GS Katma Değer", "I7"),
            ("MŞ GS Katma Değer", "J7"),
            ("Devlet GS Katma Değer", "K7"),
            ("HH GS Katma Değer", "L7"),

            ("Ürün Üzerindeki Vergi", "F25"),
            ("Ürün Üzerindeki Sübvansiyon", "K28"),
            ("Üretim Üzerideki Vergi", "F26"),
            ("Üretim Üzerindeki Sübvansiyon", "K29"),

            ("GSYİH", "M9"),

            ("Sabit Sermaye Oluşumu (Yatırım)", "M71"),
            ("MOŞ Sabit Sermaye Oluşumu (Yatırım)", "I71"),
            ("MŞ Sabit Sermaye Oluşumu (Yatırım)", "J71"),
            ("Devlet Sabit Sermaye Oluşumu (Yatırım)", "K71"),
            ("HH Sabit Sermaye Oluşumu (Yatırım)", "L71"),

            ("Gayrisafi Sabit Sermaye Oluşumu", "M72"),
            ("MOŞ Gayrisafi Sabit Sermaye Oluşumu", "I72"),
            ("MŞ Gayrisafi Sabit Sermaye Oluşumu", "J72"),
            ("Devlet Gayrisafi Sabit Sermaye Oluşumu", "K72"),
            ("HH Gayrisafi Sabit Sermaye Oluşumu", "L72"),

            ("Envanterdeki Değişimler", "M73"), 
            ("MOŞ Envanterdeki Değişimler", "I73"),
            ("MŞ Envanterdeki Değişimler", "J73"),
            ("Devlet Envanterdeki Değişimler", "K73"),
            ("HH Envanterdeki Değişimler", "L73"),

            ("Değerliler Edinim-Elden Çıkarım", "M74"), 
            ("MOŞ Değerliler Edinim-Elden Çıkarım", "I74"), 
            ("MŞ Değerliler Edinim-Elden Çıkarım", "J74"), 
            ("Devlet Değerliler Edinim-Elden Çıkarım", "K74"), 
            ("HH Değerliler Edinim-Elden Çıkarım", "L74"), 

            ("Sabit Sermaye Tüketimi (Amostisman)", "F75"),
            ("Devlet Sabit Sermaye Tüketimi (Amostisman)", "D75"),

            ("Çalışanlara Yapılan Ödemeler (Yİ -> Yİ)", "M13"),
            ("MOŞ Çalışanlara Yapılan Ödemeler (Yİ -> Yİ)", "I13"),
            ("MŞ Çalışanlara Yapılan Ödemeler (Yİ -> Yİ)", "J13"),
            ("Devlet Çalışanlara Yapılan Ödemeler (Yİ -> Yİ)", "K13"),
            ("HH Çalışanlara Yapılan Ödemeler (Yİ -> Yİ)", "L13"),

            ("Çalışanlara Yapılan Ödemeler (Faktör Geliri)", "N13"),
            ("Çalışanlara Yapılan Ödemeler (Faktör Ödemesi)", "G23"),

            ("Gayrisafi İşletme Artığı", "M18"),
            ("MOŞ Gayrisafi İşletme Artığı", "I18"),
            ("MŞ Gayrisafi İşletme Artığı", "J18"),
            ("Devlet Gayrisafi İşletme Artığı", "K18"),
            ("Hanehalkı Gayrisafi İşletme Artığı", "L18"),

            ("Net İşletme Artığı", "M20"),

            ("MOŞ Faiz Geliri", "B31"),
            ("MOŞ Dağıltılmış Gelir Kazancı", "B32"),
            ("MOŞ DYY Yeniden Yatırım Kazancı ", "B33"),
            ("MOŞ Sigorta Pol. Mülk Geliri", "B34"),
            ("MOŞ Kira Geliri", "B35"),
            ("MŞ Faiz Geliri", "C31"),
            ("MŞ Dağıltılmış Gelir Kazancı", "C32"),
            ("MŞ DYY Yeniden Yatırım Kazancı ", "C33"),
            ("MŞ Sigorta Pol. Mülk Geliri", "C34"),
            ("MŞ Kira Geliri", "C35"),
            ("Devlet Faiz Geliri", "D31"), 
            ("Devlet Dağıltılmış Gelir Kazancı", "D32"),
            ("Devlet DYY Yeniden Yatırım Kazancı ", "D33"),
            ("Devlet Sigorta Pol. Mülk Geliri", "D34"),
            ("Devlet Kira Geliri", "D35"),
            ("Hanehalkı Faiz Geliri","E31"),
            ("Hanehalkı Dağıltılmış Gelir Kazancı", "E32"),
            ("Hanehalkı DYY Yeniden Yatırım Kazancı ", "E33"),
            ("Hanehalkı Sigorta Pol. Mülk Geliri", "E34"),
            ("Hanehalkı Kira Geliri", "E35"),
            ("Dış Alem Faiz Geliri", "G31"),
            ("Dış Alem Dağıltılmış Gelir Kazancı", "G32"),
            ("Dış Alem DYY Yeniden Yatırım Kazancı ", "G33"),
            ("Dış Alem Sigorta Pol. Mülk Geliri", "G34"),
            ("Dış Alem Kira Geliri", "G35"),

            ("MOŞ Faiz Ödemesi", "I31"),
            ("MOŞ Dağıltılmış Gelir Ödemesi", "I32"),
            ("MOŞ DYY Yeniden Yatırım Ödemesi ", "I33"),
            ("MOŞ Sigorta Pol. Mülk Ödemesi", "I34"),
            ("MOŞ Kira Ödemesi", "I35"),
            ("MŞ Faiz Ödemesi", "J31"),
            ("MŞ Dağıltılmış Gelir Ödemesi", "J32"),
            ("MŞ DYY Yeniden Yatırım Ödemesi ", "J33"),
            ("MŞ Sigorta Pol. Mülk Ödemesi", "J34"),
            ("MŞ Kira Ödemesi", "J35"),
            ("Devlet Faiz Ödemesi", "K31"),
            ("Devlet Dağıltılmış Gelir Ödemesi", "K32"),
            ("Devlet DYY Yeniden Yatırım Ödemesi ", "K33"),
            ("Devlet Sigorta Pol. Mülk Ödemesi", "K34"),
            ("Devlet Kira Ödemesi", "K35"),
            ("Hanehalkı Faiz Ödemesi", "L31"),
            ("Hanehalkı Dağıltılmış Gelir Ödemesi", "L32"),
            ("Hanehalkı DYY Yeniden Yatırım Ödemesi ", "L33"),
            ("Hanehalkı Sigorta Pol. Mülk Ödemesi", "L34"),
            ("Hanehalkı Kira Ödemesi", "L35"),
            ("Dış Alem Faiz Ödemesi", "N31"),
            ("Dış Alem Dağıltılmış Gelir Ödemesi", "N32"),
            ("Dış Alem DYY Yeniden Yatırım Ödemesi ", "N33"),
            ("Dış Alem Sigorta Pol. Mülk Ödemesi", "N34"),
            ("Dış Alem Kira Ödemesi", "N35"),

            ("MOŞ Kurumlar Vergisi", "I38"),
            ("MŞ Kurumlar Vergisi", "J38"),
            ("Hanehalkı Gelir Vergisi", "L38"),

            ("MŞ Net Sosyal Katkı Gelir", "C41"), 
            ("Devlet Net Sosyal Katkı Gelir", "D41"),
            ("Hanehalkı Net Sosyal Katkı Ödeme", "L41"),

            ("MŞ Sosyal Fayda Ödeme", "J42"),
            ("Devlet Sosyal Fayda Ödeme", "K42"),
            ("Hanehalkı Sosyal Fayda Gelir", "E42"),
            ("Dış Kesim Sosyal Fayda Gelir", "G42"),

            ("MŞ Net Hayat Dışı Sigorta Pirim Geliri", "C44"),
            ("MOŞ Pirim Ödemesi", "I44"),
            ("MŞ Pirim Ödemesi", "J44"),
            ("Devlet Pirim Ödemesi", "K44"),
            ("Hanehalkı Pirim Ödemesi", "L44"),
            ("Dış Alem Pirim Ödemesi", "N44"),

            ("MŞ Hayat Dışı Sigorta Tazminat Ödemesi", "J45"),
            ("MOŞ Tazminat Geliri", "B45"),
            ("MŞ Tazminat Geliri", "C45"),
            ("Devlet Tazminat Geliri", "D45"),
            ("Hanehalkı Tazminat Geliri", "E45"),
            ("Dış Alem Tazminat Geliri", "G45"),

            ("Cari Uluslararası İşbirliği Gelir", "D46"),
            ("Cari Uluslararası İşbirliği Ödeme", "K46"),

            ("Mali Olmayan Şiket Diğer Çeşitli Transfer Geliri", "B47"),
            ("MŞ Diğer Çeşitli Transfer Geliri", "C47"),
            ("Devlet Diğer Çeşitli Transfer Geliri", "D47"),
            ("Hanehalkı Diğer Çeşitli Transfer Geliri", "E47"),
            ("Dış Alem Diğer Çeşitli Transfer Geliri", "G47"),

            ("Mali Olmayan Şiket Diğer Çeşitli Transfer Ödeme", "I47"),
            ("MŞ Diğer Çeşitli Transfer Ödeme", "J47"),
            ("Devlet Diğer Çeşitli Transfer Ödeme", "K47"),
            ("Hanehalkı Diğer Çeşitli Transfer Ödeme", "L47"),
            ("Dış Alem Diğer Çeşitli Transfer Ödeme", "N47"),

            ("Mali Olmayan Şiket Harcanabilir Gelir", "I48"),
            ("MŞ Harcanabilir Gelir", "J48"),
            ("Devlet Harcanabilir Gelir", "K48"),
            ("Hanehalkı Harcanabilir Gelir", "L48"),

            ("Hanehalkı Nihai Tüketim Harcaması", "L50"),
            ("Devlet Nihai Tüketim Harcaması", "K50"),
            ("MŞ Emeklilik Ödeme", "J53"),
            ("Hanehalkı Emeklilik Geliri", "E53"),

            ("Mali Olmayan Şiket Tasarruf", "I54"),
            ("MŞ Tasarruf", "J54"),
            ("Devlet Gayrisafi Tasarruf", "K54"),
            ("Devlet Tasarruf", "D64"),
            ("Hanehalkı Tasarruf", "L54"),

            ("Mal-Hizmet İhracatı", "N55"),
            ("Mal - Hizmet İthalatı", "G58"),
            ("Mal ve Hizmet Dengesi", "N61"),
       ]

ind   = [x[0] for x in inds_cells]
cells = [x[1] for x in inds_cells]

# %%
df = pd.DataFrame(columns = cols, index = ind)

for data in cols:
    wb = xl.load_workbook("KSH" + "_" + data +".xlsx")
    sheet = wb["Sheet1"]
    
    for row, cell in zip(ind, cells):
        value = sheet[cell].value
        df.loc[row][data] = value

# %%
df.to_excel("KSH_TOPLU.xlsx")
